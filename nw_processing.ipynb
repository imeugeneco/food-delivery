# %%
import pandas as pd
import glob
import json

path = './data/now_waiting/'
files = glob.glob(path + "/*.json")
li = []

for file in files:
    with open(file, 'r', encoding='utf-8-sig') as file:
        x = json.load(file)
    df = pd.DataFrame(x)
    li.append(df)

now_waiting = pd.concat(li, axis=0, ignore_index=True)
now_waiting.head()
# Out:
#    spot_id       id order_number   phone_number leader_name  amount  \
# 0     5185  4320414          132  010-****-5813        None    9800
# 1     5185  4320090          131  010-****-7442        None    5500
# 2     5185  4319967          130  010-****-1465        None    6400
# 3     5185  4319949          129  010-****-4184        None    5500
# 4     5185  4319922          128  010-****-1036        None    5900
#
#    amount_to_pay  quantity     status  paid  ... delivery_request  \
# 0           9800         2  completed  True  ...             None
# 1           5500         1  completed  True  ...             None
# 2           6400         1  completed  True  ...             None
# 3           5500         1  completed  True  ...             None
# 4           5900         1  completed  True  ...             None
#
#   total_discount_amount product_discount_amount  order_discount_amount  \
# 0                     0                       0                      0
# 1                     0                       0                      0
# 2                     0                       0                      0
# 3                     0                       0                      0
# 4                     0                       0                      0
#
#   order_user_coupon_discount_amount  price_before_discount  visit_count  \
# 0                                 0                   9800            1
# 1                                 0                      0            1
# 2                                 0                   6400            2
# 3                                 0                   5500            1
# 4                                 0                   5900            2
#
#                                         payment_info serving_type  \
# 0  {'status': '결제 완료', 'approval_date': 159618954...       onsite
# 1  {'status': '결제 완료', 'approval_date': None, 'pa...       onsite
# 2  {'status': '결제 완료', 'approval_date': 159618802...       onsite
# 3  {'status': '결제 완료', 'approval_date': 159618796...       onsite
# 4  {'status': '결제 완료', 'approval_date': 159618788...       onsite
#
#    user_last_ordered_date
# 0              2020-07-31
# 1              2020-07-31
# 2              2020-08-28
# 3              2020-07-31
# 4              2020-07-31
#
# [5 rows x 33 columns]

# %%
target = pd.read_csv('./compiled.csv')
print(target.columns)
target.head()
# Out:
# Index(['주문번호', '수령방법', '결제방법', '항목', '추가선택', '드레싱', '서비스타입', '주문금액', '배달팁',
#        '결제금액', '주문시각', '접수시각', '배달시각', '주소', '요청사항', '배달요청사항'],
#       dtype='object')
#          주문번호 수령방법   결제방법                                항목  \
# 0  B0LB003RY6   배달  만나서결제      닭가슴살 샐러드, 닭가슴살 샐러드, 닭가슴살 샐러드
# 1  B0LB003S70   배달   바로결제                  훈제연어 샐러드, 목살 샐러드
# 2  B0LB004ILH   배달   바로결제  목살 샐러드, 목살 샐러드, 훈제연어 샐러드, 목살 샐러드
# 3  B0LB004K4G   배달   바로결제                          훈제연어 샐러드
# 4  B0LB004S4P   배달   바로결제                    숲속 샐러드, 목살 샐러드
#
#                                                추가선택           드레싱 서비스타입  \
# 0  닭가슴살 (100g), 숲속토핑 (110g), 연어 (100g), 숲속토핑 (110g)    렌치, 렌치, 렌치    배민
# 1                                       숲속토핑 (110g)    오리엔탈, 오리엔탈    배민
# 2               고구마 (50g), 고구마 (50g), 삶은 달걀, 렌치 드레싱  렌치, 렌치, 오리엔탈    배민
# 3                                               NaN            렌치    배민
# 4                                         고구마 (50g)     발사믹, 오리엔탈    배민
#
#     주문금액   배달팁   결제금액                 주문시각                 접수시각  \
# 0  25800  3500  29300  2020-02-07 11:03:11  2020-02-07 11:03:20
# 1  17900  2000  19900  2020-02-07 11:04:50  2020-02-07 11:04:58
# 2  27200  2500  29700  2020-02-07 11:21:55  2020-02-07 11:22:48
# 3   9900  3500  13400  2020-02-07 11:24:14  2020-02-07 11:24:21
# 4  12100  3500  15600  2020-02-07 11:27:06  2020-02-07 11:27:14
#
#                   배달시각                      주소           요청사항         배달요청사항
# 0  2020-02-07 12:03:20   전북 전주시 완산구 중화산2동 ****  영수증 부탁드립니다!!!  영수증 부탁드립니다!!!
# 1  2020-02-07 12:04:58    전북 전주시 덕진구 금암1동 ****            NaN             []
# 2  2020-02-07 12:22:48   전북 전주시 완산구 중화산2동 ****            NaN             []
# 3  2020-02-07 12:24:21  전라북도 전주시 덕진구 인후2동 ****            NaN   전화주시면 바로나갈게요
# 4  2020-02-07 12:27:14     전북 전주시 완산구 서신동 ****            NaN             []

# %%
cols = ['id','serving_type', 'amount', 'amount_to_pay', 'user_comment']
df = now_waiting[cols]
df = df.rename(columns={'id':'주문번호', 
                                 'source_type':'결제방법',
                                 'serving_type': '서비스타입',
                                 'amount':'주문금액',
                                 'amount_to_pay':'결제금액',
                                 'user_comment':'요청사항'})
df.head()
# Out:
#       주문번호   서비스타입  주문금액  결제금액  요청사항
# 0  4320414  onsite  9800  9800  None
# 1  4320090  onsite  5500  5500  None
# 2  4319967  onsite  6400  6400  None
# 3  4319949  onsite  5500  5500  None
# 4  4319922  onsite  5900  5900  None

# %%
import datetime

def get_timestamps(timestamp_list):
    registered_ts = timestamp_list.get('registered')/1000
    registered_dt = datetime.datetime.fromtimestamp(int(registered_ts)).strftime('%Y-%m-%d %H:%M:%S')
  
    return pd.Series((registered_dt))

def get_order_details(order_list):
    method = []
    items = []
    toppings = []
    sauce = []
    
    for order in order_list:
        order_type = order.get('type')
        order_content = order.get('content')
        quantity = order.get('quantity')
        
        if order_type=='product':
            items = items + [order.get('name')] * quantity
        elif order_type=='product_option_item':
            if '수령방식' in order_content:
                method.append(order_content[order_content.find(' ')+1:])
            elif '소스' in order_content:
                sauce.append(order_content[order_content.find(' ')+1:])
            else:
                toppings = toppings + [order.get('name')] * quantity
                
    method = (', ').join(method)
    items = (', ').join(items)
    toppings = (', ').join(toppings)
    sauce = (', ').join(sauce)
    
    return pd.Series((method, items, toppings, sauce))

# %%
df[['수령방법', '항목', '추가선택', '드레싱']] = now_waiting.apply(lambda row: pd.Series(get_order_details(row['order_items'])), axis=1)
df[['주문시각']] = now_waiting.apply(lambda row: pd.Series(get_timestamps(row['timestamps'])), axis=1)
df.head()
# Out:
#       주문번호   서비스타입  주문금액  결제금액  요청사항        수령방법               항목  \
# 0  4320414  onsite  9800  9800  None  매장식사, 매장식사  목살 샐러드, 이너프 샐러드
# 1  4320090  onsite  5500  5500  None          포장           숲속 샐러드
# 2  4319967  onsite  6400  6400  None          포장           목살 샐러드
# 3  4319949  onsite  5500  5500  None          포장           숲속 샐러드
# 4  4319922  onsite  5900  5900  None        매장식사           목살 샐러드
#
#                추가선택       드레싱                 주문시각
# 0                    발사믹, 발사믹  2020-07-31 18:58:54
# 1              강낭콩X      오리엔탈  2020-07-31 18:40:16
# 2  강낭콩 X, 올리브 X, 계란      오리엔탈  2020-07-31 18:33:37
# 3                        오리엔탈  2020-07-31 18:32:41
# 4             올리브 X        렌치  2020-07-31 18:31:14

# %%
target_cols = target.columns
df['주소'] = 'X'
df['배달팁'] = 0
df['결제방법'] = '나우웨이팅 POS'
df['접수시각'] = '-' 
df['배달시각'] = '-'
df['배달요청사항'] = '-'
df = df[target_cols]
df.head()
# Out:
#       주문번호        수령방법       결제방법               항목              추가선택  \
# 0  4320414  매장식사, 매장식사  나우웨이팅 POS  목살 샐러드, 이너프 샐러드
# 1  4320090          포장  나우웨이팅 POS           숲속 샐러드              강낭콩X
# 2  4319967          포장  나우웨이팅 POS           목살 샐러드  강낭콩 X, 올리브 X, 계란
# 3  4319949          포장  나우웨이팅 POS           숲속 샐러드
# 4  4319922        매장식사  나우웨이팅 POS           목살 샐러드             올리브 X
#
#         드레싱   서비스타입  주문금액  배달팁  결제금액                 주문시각 접수시각 배달시각 주소  요청사항  \
# 0  발사믹, 발사믹  onsite  9800    0  9800  2020-07-31 18:58:54    -    -  X  None
# 1      오리엔탈  onsite  5500    0  5500  2020-07-31 18:40:16    -    -  X  None
# 2      오리엔탈  onsite  6400    0  6400  2020-07-31 18:33:37    -    -  X  None
# 3      오리엔탈  onsite  5500    0  5500  2020-07-31 18:32:41    -    -  X  None
# 4        렌치  onsite  5900    0  5900  2020-07-31 18:31:14    -    -  X  None
#
#   배달요청사항
# 0      -
# 1      -
# 2      -
# 3      -
# 4      -

# %%
target.head()
# Out:
#          주문번호 수령방법   결제방법                                항목  \
# 0  B0LB003RY6   배달  만나서결제      닭가슴살 샐러드, 닭가슴살 샐러드, 닭가슴살 샐러드
# 1  B0LB003S70   배달   바로결제                  훈제연어 샐러드, 목살 샐러드
# 2  B0LB004ILH   배달   바로결제  목살 샐러드, 목살 샐러드, 훈제연어 샐러드, 목살 샐러드
# 3  B0LB004K4G   배달   바로결제                          훈제연어 샐러드
# 4  B0LB004S4P   배달   바로결제                    숲속 샐러드, 목살 샐러드
#
#                                                추가선택           드레싱 서비스타입  \
# 0  닭가슴살 (100g), 숲속토핑 (110g), 연어 (100g), 숲속토핑 (110g)    렌치, 렌치, 렌치    배민
# 1                                       숲속토핑 (110g)    오리엔탈, 오리엔탈    배민
# 2               고구마 (50g), 고구마 (50g), 삶은 달걀, 렌치 드레싱  렌치, 렌치, 오리엔탈    배민
# 3                                               NaN            렌치    배민
# 4                                         고구마 (50g)     발사믹, 오리엔탈    배민
#
#     주문금액   배달팁   결제금액                 주문시각                 접수시각  \
# 0  25800  3500  29300  2020-02-07 11:03:11  2020-02-07 11:03:20
# 1  17900  2000  19900  2020-02-07 11:04:50  2020-02-07 11:04:58
# 2  27200  2500  29700  2020-02-07 11:21:55  2020-02-07 11:22:48
# 3   9900  3500  13400  2020-02-07 11:24:14  2020-02-07 11:24:21
# 4  12100  3500  15600  2020-02-07 11:27:06  2020-02-07 11:27:14
#
#                   배달시각                      주소           요청사항         배달요청사항
# 0  2020-02-07 12:03:20   전북 전주시 완산구 중화산2동 ****  영수증 부탁드립니다!!!  영수증 부탁드립니다!!!
# 1  2020-02-07 12:04:58    전북 전주시 덕진구 금암1동 ****            NaN             []
# 2  2020-02-07 12:22:48   전북 전주시 완산구 중화산2동 ****            NaN             []
# 3  2020-02-07 12:24:21  전라북도 전주시 덕진구 인후2동 ****            NaN   전화주시면 바로나갈게요
# 4  2020-02-07 12:27:14     전북 전주시 완산구 서신동 ****            NaN             []

# %%
# with open('./누적데이터.csv', 'a') as old_file: df.to_csv('./new데이터.csv', header=False, index=False)
df.to_csv('./nw_processed.csv')

# %%
df
# Out:
#          주문번호        수령방법       결제방법                        항목  \
# 0     4320414  매장식사, 매장식사  나우웨이팅 POS           목살 샐러드, 이너프 샐러드
# 1     4320090          포장  나우웨이팅 POS                    숲속 샐러드
# 2     4319967          포장  나우웨이팅 POS                    목살 샐러드
# 3     4319949          포장  나우웨이팅 POS                    숲속 샐러드
# 4     4319922        매장식사  나우웨이팅 POS                    목살 샐러드
# ...       ...         ...        ...                       ...
# 3154  4610442  포장, 포장, 포장  나우웨이팅 POS  닭가슴살 샐러드, 목살 샐러드, 목살 샐러드
# 3155  4610130          포장  나우웨이팅 POS                    목살 샐러드
# 3156  4610003          포장  나우웨이팅 POS                  닭가슴살 샐러드
# 3157  4609987        매장식사  나우웨이팅 POS                    숲속 샐러드
# 3158  4609976  매장식사, 매장식사  나우웨이팅 POS        닭가슴살 샐러드, 훈제연어 샐러드
#
#                                                    추가선택             드레싱  \
# 0                                                              발사믹, 발사믹
# 1                                                  강낭콩X            오리엔탈
# 2                                      강낭콩 X, 올리브 X, 계란            오리엔탈
# 3                                                                  오리엔탈
# 4                                                 올리브 X              렌치
# ...                                                 ...             ...
# 3154  고구마(50g), 고구마(100g), 올리브 X, 할라피뇨 X, 양파 X, 아몬드 ...  오리엔탈, 렌치, 오리엔탈
# 3155                                   삶은달걀 추가, 삶은달걀 추가              렌치
# 3156                                              아몬드 X          드레싱 제외
# 3157                             할라피뇨 X, 양파 X, 고구마(50g)              렌치
# 3158                                          고구마(100g)        오리엔탈, 렌치
#
#        서비스타입   주문금액  배달팁   결제금액                 주문시각 접수시각 배달시각 주소  요청사항 배달요청사항
# 0     onsite   9800    0   9800  2020-07-31 18:58:54    -    -  X  None      -
# 1     onsite   5500    0   5500  2020-07-31 18:40:16    -    -  X  None      -
# 2     onsite   6400    0   6400  2020-07-31 18:33:37    -    -  X  None      -
# 3     onsite   5500    0   5500  2020-07-31 18:32:41    -    -  X  None      -
# 4     onsite   5900    0   5900  2020-07-31 18:31:14    -    -  X  None      -
# ...      ...    ...  ...    ...                  ...  ...  ... ..   ...    ...
# 3154  onsite  21500    0  21500  2020-08-17 12:42:16    -    -  X  None      -
# 3155  onsite   7400    0   7400  2020-08-17 12:28:27    -    -  X  None      -
# 3156  onsite   5900    0   5900  2020-08-17 12:22:38    -    -  X  None      -
# 3157  onsite   6600    0   4600  2020-08-17 12:21:56    -    -  X  None      -
# 3158  onsite  14200    0  14200  2020-08-17 12:21:19    -    -  X  None      -
#
# [3159 rows x 16 columns]
